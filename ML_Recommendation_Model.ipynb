# %%
import pandas as pd
from sklearn.cluster import KMeans
from scipy import spatial
import operator

# %%
df = pd.read_csv('data_for_ml.csv')

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.head()
# Out:
#                                                title  Year  average_rating  \
# 0                                   Inception (2010)  2010            4.44
# 1       Eternal Sunshine of the Spotless Mind (2004)  2004            4.51
# 2                            Dark Knight, The (2008)  2008            4.38
# 3                               Prestige, The (2006)  2006            4.34
# 4  Lord of the Rings: The Fellowship of the Ring,...  2001            4.45
#
#    rating_count  Animation  Adventure  Mystery  Drama  Action  Romance  ...  \
# 0          8817          0          0        1      1       1        0  ...
# 1          4507          0          0        0      1       0        1  ...
# 2          3598          0          0        0      1       1        0  ...
# 3          3598          0          0        1      1       0        0  ...
# 4          3372          0          1        0      0       0        0  ...
#
# ...

# %%
print(df.loc(df['title'] == 'Inception (2010)'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(df['Animation':'Horror'])
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:3735, in DataFrame.__getitem__(self, key)
#    3733 # Do we have a slicer (on rows)?
#    3734 if isinstance(key, slice):
# -> 3735     indexer = self.index._convert_slice_indexer(key, kind="getitem")
#    3736     if isinstance(indexer, np.ndarray):
#    3737         # reachable with DatetimeIndex
#    3738         indexer = lib.maybe_indices_to_slice(
#    3739             indexer.astype(np.intp, copy=False), len(self)
#    3740         )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:4101, in Index._convert_slice_indexer(self, key, kind)
#    4097 if kind == "getitem":
# ...
